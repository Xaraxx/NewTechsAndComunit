# %% [markdown]
# <a href="https://colab.research.google.com/github/Xaraxx/NewTechsAndComunit/blob/master/Img_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Procesamiento de imagen con python

# %%
# !wget "http://www.aqueenofmagic.com/wp-content/uploads/2018/04/queen-i-want-to-break-free-works-1-678x360-678x360.jpg"
# !ls


import cv2
import numpy as np
from matplotlib import pyplot as plt


img_queen = cv2.imread("queen-i-want-to-break-free-works-1-678x360-678x360.jpg")
img_color = cv2.cvtColor(img_queen, cv2.COLOR_BGR2RGB)
queen2 = img_color.copy()
 

plt.imshow(img_color)
plt.show()
# Out:
# --2019-03-23 19:38:12--  http://www.aqueenofmagic.com/wp-content/uploads/2018/04/queen-i-want-to-break-free-works-1-678x360-678x360.jpg
# Resolving www.aqueenofmagic.com (www.aqueenofmagic.com)... 37.152.88.89
# Connecting to www.aqueenofmagic.com (www.aqueenofmagic.com)|37.152.88.89|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60681 (59K) [image/jpeg]
# Saving to: ‘queen-i-want-to-break-free-works-1-678x360-678x360.jpg.34’
#
# queen-i-want-to-bre 100%[===================>]  59.26K   262KB/s    in 0.2s
#
# 2019-03-23 19:38:12 (262 KB/s) - ‘queen-i-want-to-break-free-works-1-678x360-678x360.jpg.34’ saved [60681/60681]
#
# 5819FCBB-late-queen-singer-freddie-mercury-on-i-want-to-break-free-music-video-it-still-makes-me-chuckle-every-time-i-see-it-rare-bbc-1-audio-interview-streaming-image.jpg
# ...

# %%
# Face Freddy Mercury
import PIL

crop_img = img_color[50:140, 390:440]

plt.imshow(crop_img)
cv2.waitKey(0)

template = crop_img
w,h = template.shape[::-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-8c8a95d4b183> in <module>()
#       7
#       8 template = crop_img
# ----> 9 w,h = template.shape[::-1]
#      10 #area = (50, 390, 420, 50)
#      11 #cropped_img = face.crop(area)
#
# ValueError: too many values to unpack (expected 2)

# %%
methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR',
            'cv2.TM_CCORR_NORMED', 'cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED']

for meth in methods:
    img_color = queen2.copy()
    method = eval(meth)

    # Apply template Matching
    res = cv2.matchTemplate(img_color,template,method)
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)

    # If the method is TM_SQDIFF or TM_SQDIFF_NORMED, take minimum
    if method in [cv2.TM_SQDIFF, cv2.TM_SQDIFF_NORMED]:
        top_left = min_loc
    else:
        top_left = max_loc
    bottom_right = (top_left[0] + w, top_left[1] + h)

    cv2.rectangle(img_color,top_left, bottom_right, 255, 2)

    plt.subplot(121),plt.imshow(res,cmap = 'gray')
    plt.title('Matching Result'), plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(img_color,cmap = 'gray')
    plt.title('Detected Point'), plt.xticks([]), plt.yticks([])
    plt.suptitle(meth)

    plt.show()

# %%
#cargando otra imagen
# !wget "http://www.javiduque.com/wp-content/uploads/2018/12/its-a-hard-life-queen-1984-3.jpg"

queen = cv2.imread("its-a-hard-life-queen-1984-3.jpg")

colorQueen = cv2.cvtColor(queen, cv2.COLOR_BGR2RGB)

plt.imshow(colorQueen)
plt.show()

#img = cv2.medianBlur(queen,3)
#cimg = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)

#circles = cv2.HoughCircles(img,cv2.HOUGH_GRADIENT,1,20,
#                            param1=50,param2=30,minRadius=0,maxRadius=0)

#circles = np.uint16(np.around(circles))
#for i in circles[0,:]:
    # draw the outer circle
#    cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
    # draw the center of the circle
#    cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)

#cv2.imshow('detected circles',cimg)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
# Out:
# --2019-03-23 19:58:27--  http://www.javiduque.com/wp-content/uploads/2018/12/its-a-hard-life-queen-1984-3.jpg
# Resolving www.javiduque.com (www.javiduque.com)... 37.187.222.132
# Connecting to www.javiduque.com (www.javiduque.com)|37.187.222.132|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 155000 (151K) [image/jpeg]
# Saving to: ‘its-a-hard-life-queen-1984-3.jpg.12’
#
# its-a-hard-life-que 100%[===================>] 151.37K   512KB/s    in 0.3s
#
# 2019-03-23 19:58:28 (512 KB/s) - ‘its-a-hard-life-queen-1984-3.jpg.12’ saved [155000/155000]

# %%
#queen3 = img.copy(queen)
